# %%
import pandas as pd

# %%
demo_df = pd.read_csv('Demographics_Data.csv')
demo_df.shape
demo_df.head()
# Out:
#                id         Geographic Area Name  Total population  \
# 0  0500000US01103       Morgan County, Alabama            119089
# 1  0500000US06031     Kings County, California            151366
# 2  0500000US06053  Monterey County, California            435594
# 3  0500000US06057    Nevada County, California             99696
# 4  0500000US06089    Shasta County, California            180040
#
#    Total population Male  Percent Total population Male  \
# 0                  59216                           49.7
# 1                  83591                           55.2
# 2                 221011                           50.7
# 3                  48808                           49.0
# 4                  88679                           49.3
#
#    Total population Female  Percent Total population Female  \
# 0                    59873                             50.3
# 1                    67775                             44.8
# ...

# %%
demo_df.shape
# Out:
# (838, 49)
